# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
tqdm.pandas()
import fileinput
import json

import pickle

# %%
df = pd.read_pickle("p:/uni/nlp/WashingtonPost_v4/data/v4/12_Split.pkl")

# %%
df
# Out:
#                                                     0     \
# 0      {'content': 'Sports', 'mime': 'text/plain', 't...
# 1      {'content': 'Local', 'mime': 'text/plain', 'ty...
# 2      {'content': 'Redskins/NFL', 'mime': 'text/plai...
# 3      {'content': 'Opinions', 'mime': 'text/plain', ...
# 4      {'content': 'Sports', 'mime': 'text/plain', 't...
# ...                                                  ...
# 11995  {'content': 'Entertainment', 'mime': 'text/pla...
# 11996  {'content': 'Books', 'mime': 'text/plain', 'se...
# 11997  {'content': 'Capital Weather Gang', 'mime': 't...
# 11998  {'content': 'Voraciously', 'mime': 'text/plain...
# 11999  {'content': 'Style', 'mime': 'text/plain', 'se...
#
#                                                     1     \
# 0      {'content': 'NFL playoff picture: A breakdown ...
# 1      {'content': 'Where are they now?', 'mime': 'te...
# 2      {'content': 'NFL playoffs: Detroit Lions at Ne...
# ...
